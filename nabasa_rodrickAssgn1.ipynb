# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('D:\\learn python\\2018CrimeStatisticsByCategoryOfCrime.csv')
df.head()
# Out:
#   Unnamed: 0             Unnamed: 1 REPORTED CASES           Unnamed: 3  \
# 0        NaN                    NaN            NaN                  NaN
# 1        NaN                    NaN   Totals Cases  Cases under Inquiry
# 2      S/No.  CASE/CRIME INCIDENCES              1                    2
# 3        NaN              HOMICIDES            NaN                  NaN
# 4          1   Death  (by shooting)            190                  117
#
#          Unnamed: 4            Unnamed: 5                 PERFOMANCE  \
# 0               NaN                   NaN                        NaN
# 1  Not Detected/NPW  Cases taken to court  Cases submitted toDPP/RSA
# 2                 3                     4                          5
# 3               NaN                   NaN                        NaN
# 4                29                    44                         74
#
#                Unnamed: 7             Unnamed: 8       Unnamed: 9  ...  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 127 entries, 0 to 126
# Data columns (total 38 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Unnamed: 0                   95 non-null     object
#  1   Unnamed: 1                   125 non-null    object
#  2   REPORTED CASES               125 non-null    object
#  3   Unnamed: 3                   125 non-null    object
#  4   Unnamed: 4                   125 non-null    object
#  5   Unnamed: 5                   125 non-null    object
#  6   PERFOMANCE                   125 non-null    object
#  7   Unnamed: 7                   125 non-null    object
#  8   Unnamed: 8                   125 non-null    object
#  9   Unnamed: 9                   125 non-null    object
#  10  Unnamed: 10                  125 non-null    object
#  11  PERSONS TAKEN TO COURT       126 non-null    object
#  12  Unnamed: 12                  124 non-null    object
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 1', 'REPORTED CASES', 'Unnamed: 3',
#        'Unnamed: 4', 'Unnamed: 5', 'PERFOMANCE', 'Unnamed: 7', 'Unnamed: 8',
#        'Unnamed: 9', 'Unnamed: 10', 'PERSONS TAKEN TO COURT', 'Unnamed: 12',
#        'Unnamed: 13', 'Unnamed: 14', 'Unnamed: 15', 'Unnamed: 16',
#        'Unnamed: 17', 'Unnamed: 18', 'Unnamed: 19', 'Unnamed: 20',
#        'Unnamed: 21', 'SENTENCES IMPOSED BY COURTS', 'Unnamed: 23',
#        'Unnamed: 24', 'Unnamed: 25', 'Unnamed: 26', 'Unnamed: 27',
#        'Unnamed: 28', 'Unnamed: 29', 'Unnamed: 30', 'Unnamed: 31',
#        'Unnamed: 32', 'Unnamed: 33', 'Unnamed: 34', 'Unnamed: 35',
#        'Unnamed: 36', 'Unnamed: 37'],
#       dtype='object')

# %%
df.shape
# Out:
# (127, 38)

# %%
#check for missing values 
print(df.isnull().sum())
# Out:
# Unnamed: 0                     32
# Unnamed: 1                      2
# REPORTED CASES                  2
# Unnamed: 3                      2
# Unnamed: 4                      2
# Unnamed: 5                      2
# PERFOMANCE                      2
# Unnamed: 7                      2
# Unnamed: 8                      2
# Unnamed: 9                      2
# Unnamed: 10                     2
# PERSONS TAKEN TO COURT          1
# Unnamed: 12                     3
# Unnamed: 13                     3
# Unnamed: 14                     3
# Unnamed: 15                     1
# Unnamed: 16                     3
# Unnamed: 17                     3
# Unnamed: 18                     3
# Unnamed: 19                    18
# Unnamed: 20                    18
# Unnamed: 21                    18
# SENTENCES IMPOSED BY COURTS    18
# Unnamed: 23                    19
# Unnamed: 24                    19
# Unnamed: 25                    18
# Unnamed: 26                    18
# ...

# %%
df = df[1:]#remove first row containing unclear column names

# %%
threshold = 0.5  # Set a threshold (e.g., 50%) to drop columns with more missing values
df = df.dropna(thresh=len(df) * threshold, axis=1)

# %%
#display all columns
pd.set_option('display.max_columns', None)
#display all rows 
pd.set_option('display.max_rows', None)

#display entire dataframe without truncation
print(df.to_string(index=False))
# Out:
# Unnamed: 0                                   Unnamed: 1 REPORTED CASES Unnamed: 3 Unnamed: 4 Unnamed: 5 PERFOMANCE Unnamed: 7 Unnamed: 8 Unnamed: 9 Unnamed: 10 PERSONS TAKEN TO COURT Unnamed: 12 Unnamed: 13 Unnamed: 14 Unnamed: 15 Unnamed: 16 Unnamed: 17 Unnamed: 18 Unnamed: 19 Unnamed: 20 Unnamed: 21 SENTENCES IMPOSED BY COURTS Unnamed: 23 Unnamed: 24 Unnamed: 25 Unnamed: 26 Unnamed: 27 Unnamed: 28 Unnamed: 29 Unnamed: 30 Unnamed: 31 Unnamed: 32 Unnamed: 33 Unnamed: 34 Unnamed: 35     Unnamed: 36    Unnamed: 37
# ...

# %%
#drop missing values
threshold = 2
df = df.dropna(thresh=threshold)

# %%
#fill misssing values with the mean
#check if dtype is not object
for column in df.columns:
    if df[column].dtype.name == "object":
        continue
    df[column].fillna(df[column].mean(),inplace=TRUE)

#print  the cleaned data
print(df.head())
# Out:
#   Unnamed: 0             Unnamed: 1 REPORTED CASES           Unnamed: 3  \
# 0        NaN                    NaN            NaN                  NaN
# 1        NaN                    NaN   Totals Cases  Cases under Inquiry
# 2      S/No.  CASE/CRIME INCIDENCES              1                    2
# 4          1   Death  (by shooting)            190                  117
# 5          2  Death (by mob action)            636                  431
#
#          Unnamed: 4            Unnamed: 5                 PERFOMANCE  \
# 0               NaN                   NaN                        NaN
# 1  Not Detected/NPW  Cases taken to court  Cases submitted toDPP/RSA
# 2                 3                     4                          5
# 4                29                    44                         74
# 5               109                    96                        176
#
#                Unnamed: 7             Unnamed: 8       Unnamed: 9  \
# ...

# %%
missing_values = df.isnull().sum()
print(missing_values)
# Out:
# Unnamed: 0                     31
# Unnamed: 1                      2
# REPORTED CASES                  1
# Unnamed: 3                      1
# Unnamed: 4                      1
# Unnamed: 5                      1
# PERFOMANCE                      1
# Unnamed: 7                      1
# Unnamed: 8                      1
# Unnamed: 9                      1
# Unnamed: 10                     1
# PERSONS TAKEN TO COURT          0
# Unnamed: 12                     2
# Unnamed: 13                     2
# Unnamed: 14                     2
# Unnamed: 15                     0
# Unnamed: 16                     2
# Unnamed: 17                     2
# Unnamed: 18                     2
# Unnamed: 19                    17
# Unnamed: 20                    17
# Unnamed: 21                    17
# SENTENCES IMPOSED BY COURTS    17
# Unnamed: 23                    18
# Unnamed: 24                    18
# Unnamed: 25                    17
# Unnamed: 26                    17
# ...

# %%
df= df.dropna()

# %%
# Check for missing values
missing_values = df["SENTENCES IMPOSED BY COURTS"].isnull()

# Print the missing values
print(missing_values)
# Out:
# 4      False
# 5      False
# 6      False
# 7      False
# 8      False
# 9      False
# 12     False
# 13     False
# 14     False
# 15     False
# 16     False
# 17     False
# 18     False
# 19     False
# 20     False
# 21     False
# 22     False
# 28     False
# 29     False
# 30     False
# 43     False
# 44     False
# 45     False
# 46     False
# 47     False
# 50     False
# 51     False
# 52     False
# 53     False
# 54     False
# 55     False
# 56     False
# 57     False
# 58     False
# 59     False
# 60     False
# 61     False
# 62     False
# 63     False
# 64     False
# 67     False
# 68     False
# 69     False
# 70     False
# 72     False
# 75     False
# 76     False
# 77     False
# 80     False
# 81     False
# 82     False
# 83     False
# 84     False
# 85     False
# 86     False
# 87     False
# 88     False
# 89     False
# 90     False
# 91     False
# 92     False
# 93     False
# 94     False
# 95     False
# 98     False
# 99     False
# ...

# %%
df['REPORTED CASES'] = pd.to_numeric(df['REPORTED CASES'], errors='coerce')
df['PERFOMANCE'] = pd.to_numeric(df['PERFOMANCE'], errors='coerce')
df['SENTENCES IMPOSED BY COURTS'] = pd.to_numeric(df['SENTENCES IMPOSED BY COURTS'], errors='coerce')
df['PERSONS TAKEN TO COURT'] = pd.to_numeric(df['PERSONS TAKEN TO COURT'], errors='coerce')

# %%
import matplotlib.pyplot as plt
import seaborn as sns

#plot the distribution of the target variable

plt.hist(df["SENTENCES IMPOSED BY COURTS"])
plt.show()

# %%
#plot the correlation matrix

for column in df.columns:
    df[column] = pd.to_numeric(df[column], errors='coerce')
sns.heatmap(df.corr(), annot=True)
plt.show()

# %%
for column in df.columns:
    if df[column].isnull().any():
        print(f"The column {column} has {df[column].isnull().sum()} missing values.")
# Out:
# The column REPORTED CASES has 28 missing values.
# The column PERFOMANCE has 24 missing values.
# The column PERSONS TAKEN TO COURT has 27 missing values.
# The column SENTENCES IMPOSED BY COURTS has 20 missing values.

# %%
for column in df.columns:
    df[column] = pd.to_numeric(df[column], errors='coerce')

for column in df.columns:
    print(f"The mean of {column} is {df[column].mean()}.")
    print(f"The standard deviation of {column} is {df[column].std()}.")
    print(f"The minimum value of {column} is {df[column].min()}.")
    print(f"The maximum value of {column} is {df[column].max()}.")
# Out:
# The mean of Unnamed: 0 is 54.02439024390244.
# The standard deviation of Unnamed: 0 is 28.640373648226504.
# The minimum value of Unnamed: 0 is 2.
# The maximum value of Unnamed: 0 is 100.
# The mean of Unnamed: 1 is nan.
# The standard deviation of Unnamed: 1 is nan.
# The minimum value of Unnamed: 1 is nan.
# The maximum value of Unnamed: 1 is nan.
# The mean of REPORTED CASES is 261.1851851851852.
# The standard deviation of REPORTED CASES is 210.67288282402305.
# The minimum value of REPORTED CASES is 3.0.
# The maximum value of REPORTED CASES is 898.0.
# The mean of Unnamed: 3 is 171.33870967741936.
# The standard deviation of Unnamed: 3 is 198.4108953536299.
# The minimum value of Unnamed: 3 is 1.0.
# The maximum value of Unnamed: 3 is 885.0.
# The mean of Unnamed: 4 is 136.46666666666667.
# The standard deviation of Unnamed: 4 is 184.36445727781867.
# The minimum value of Unnamed: 4 is 1.0.
# The maximum value of Unnamed: 4 is 956.0.
# ...

# %%
for column in df.columns:
    if df[column].isnull().any():
        df[column].fillna(df[column].mean(), inplace=True)

# %%
def detect_outliers(df, column):
    q1 = df[column].quantile(0.25)
    q3 = df[column].quantile(0.75)
    iqr = q3 - q1
    lower_bound = q1 - 1.5 * iqr
    upper_bound = q3 + 1.5 * iqr
    return df[column].loc[(df[column] < lower_bound) | (df[column] > upper_bound)]

outliers = detect_outliers(df, "REPORTED CASES")
df.drop(outliers.index, inplace=True)

# %%
import matplotlib.pyplot as plt

plt.bar(df["REPORTED CASES"].value_counts().index, df["REPORTED CASES"].value_counts())
plt.xlabel("Column Name")
plt.ylabel("Count")
plt.show()
